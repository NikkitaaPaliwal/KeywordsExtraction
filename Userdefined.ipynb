# %%
#installing required libraries

# !pip install spacy
# !python -m spacy download en
# !pip install nltk
# !pip install pattern
# !pip install genism
# !pip install spaCy
# !pip install TextBlob
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# ...
# ERROR: Could not find a version that satisfies the requirement genism (from versions: none)
# ERROR: No matching distribution found for genism
# ...

# %%
#importing required libraries

import nltk
import spacy
import en_core_web_sm
nltk.download()
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger') 
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('maxent_ne_chunker')
from pprint import pprint
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import PunktSentenceTokenizer
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk.chunk import conlltags2tree, tree2conlltags
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#input sentence for which you want to extract keywords

sen = input('Enter the sentence from which you want to extract keywords: ')
# Out:
# Enter the sentence from which you want to extract keywords: Reports about Aaron Rodgers’s interminable unhappiness in Green Bay ricocheted across the internet and teams’ draft headquarters, temporarily overshadowing Trevor Lawrence, Zach Wilson and the three other quarterbacks selected in the first round.

# %%
#Then we apply word tokenization and part-of-speech tagging to the sentence.

nltk.download('averaged_perceptron_tagger')
def func(sent):
  sent = word_tokenize(sent)
  sent = pos_tag(sent)
  return sent
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
sent = func(sen)
sent
#Here we get a list of tuples containing the individual words in the sentence and their associated part-of-speech.
# Out:
# [('Reports', 'NNS'),
#  ('about', 'IN'),
#  ('Aaron', 'NNP'),
#  ('Rodgers', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('interminable', 'JJ'),
#  ('unhappiness', 'NN'),
#  ('in', 'IN'),
#  ('Green', 'NNP'),
#  ('Bay', 'NNP'),
#  ('ricocheted', 'VBD'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('internet', 'NN'),
#  ('and', 'CC'),
#  ('teams', 'NNS'),
#  ('’', 'VBP'),
#  ('draft', 'NN'),
#  ('headquarters', 'NN'),
#  (',', ','),
#  ('temporarily', 'RB'),
#  ('overshadowing', 'VBG'),
#  ('Trevor', 'NNP'),
#  ('Lawrence', 'NNP'),
#  (',', ','),
#  ('Zach', 'NNP'),
#  ('Wilson', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('three', 'CD'),
#  ('other', 'JJ'),
#  ('quarterbacks', 'NNS'),
#  ('selected', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('round', 'NN'),
#  ('.', '.')]

# %%
#This is a fixed chunk pattern determiner(DT), followed by any number of adjectives(JJ), and then a noun (NN)

pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
#Using this pattern, we create a chunk parser and test it on our sentence.

cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
cs
#The output can be read as a tree or a hierarchy with S as the first level, denoting sentence. we can also display it graphically.
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.7/dist-packages/nltk/tree.py in _repr_png_(self)
#     717         from nltk.draw.util import CanvasFrame
#     718         from nltk.internals import find_binary
# --> 719         _canvas_frame = CanvasFrame()
#     720         widget = tree_to_treesegment(_canvas_frame.canvas(), self)
#     721         _canvas_frame.add_widget(widget)
#
# /usr/local/lib/python3.7/dist-packages/nltk/draw/util.py in __init__(self, parent, **kw)
#    1651         # If no parent was given, set up a top-level window.
# ...

# %%
#Based on this training corpus, we can construct a tagger that can be used to label new sentences; and use the nltk.chunk.conlltags2tree() function to convert the tag sequences into a chunk tree.

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Reports', 'NNS', 'O'),
#  ('about', 'IN', 'O'),
#  ('Aaron', 'NNP', 'O'),
#  ('Rodgers', 'NNP', 'O'),
#  ('’', 'NNP', 'O'),
#  ('s', 'VBD', 'O'),
#  ('interminable', 'JJ', 'B-NP'),
#  ('unhappiness', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('Green', 'NNP', 'O'),
#  ('Bay', 'NNP', 'O'),
#  ('ricocheted', 'VBD', 'O'),
#  ('across', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('internet', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('teams', 'NNS', 'O'),
#  ('’', 'VBP', 'O'),
#  ('draft', 'NN', 'B-NP'),
#  ('headquarters', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('temporarily', 'RB', 'O'),
#  ('overshadowing', 'VBG', 'O'),
#  ('Trevor', 'NNP', 'O'),
#  ('Lawrence', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Zach', 'NNP', 'O'),
#  ('Wilson', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'O'),
#  ('three', 'CD', 'O'),
#  ('other', 'JJ', 'O'),
#  ('quarterbacks', 'NNS', 'O'),
#  ('selected', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('first', 'JJ', 'I-NP'),
# ...

# %%
#nltk.ne_chunk(), we can recognize named entities using a classifier
 
nltk.download('words')
ne_tree = ne_chunk(pos_tag(word_tokenize(sen)))
print(ne_tree)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   Reports/NNS
#   about/IN
#   (PERSON Aaron/NNP Rodgers/NNP)
#   ’/NNP
#   s/VBD
#   interminable/JJ
#   unhappiness/NN
#   in/IN
#   (GPE Green/NNP)
#   Bay/NNP
#   ricocheted/VBD
#   across/IN
#   the/DT
#   internet/NN
#   and/CC
#   teams/NNS
#   ’/VBP
#   draft/NN
#   headquarters/NN
#   ,/,
#   temporarily/RB
#   overshadowing/VBG
#   (PERSON Trevor/NNP Lawrence/NNP)
#   ,/,
#   (PERSON Zach/NNP Wilson/NNP)
#   and/CC
#   the/DT
#   three/CD
#   other/JJ
#   quarterbacks/NNS
#   selected/VBN
#   in/IN
#   the/DT
#   first/JJ
#   round/NN
#   ./.)

# %%
#Importing spacy for NER, POS tagging, dependency parsing, word vectors, and entity recognition

from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = spacy.load('en_core_web_sm')

# %%
# printing of words and the entity to which they belong
doc = nlp(input('Enter the sentence: '))
pprint([(X.text, X.label) for X in doc.ents])
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# Enter the sentence: Reports about Aaron Rodgers’s interminable unhappiness in Green Bay ricocheted across the internet and teams’ draft headquarters, temporarily overshadowing Trevor Lawrence, Zach Wilson and the three other quarterbacks selected in the first round.
# [('Aaron Rodgers', 380),
#  ('Green Bay', 385),
#  ('Trevor Lawrence', 383),
#  ('Zach Wilson', 380),
#  ('three', 397),
#  ('first', 396)]
# [(Reports, 'O', ''),
#  (about, 'O', ''),
#  (Aaron, 'B', 'PERSON'),
#  (Rodgers, 'I', 'PERSON'),
#  (’s, 'O', ''),
#  (interminable, 'O', ''),
#  (unhappiness, 'O', ''),
#  (in, 'O', ''),
#  (Green, 'B', 'LOC'),
#  (Bay, 'I', 'LOC'),
#  (ricocheted, 'O', ''),
#  (across, 'O', ''),
#  (the, 'O', ''),
#  (internet, 'O', ''),
#  (and, 'O', ''),
#  (teams, 'O', ''),
#  (’, 'O', ''),
#  (draft, 'O', ''),
#  (headquarters, 'O', ''),
#  (,, 'O', ''),
#  (temporarily, 'O', ''),
#  (overshadowing, 'O', ''),
#  (Trevor, 'B', 'ORG'),
#  (Lawrence, 'I', 'ORG'),
#  (,, 'O', ''),
# ...

# %%
#importing of libraries for extraction of named entity from the article
from bs4 import BeautifulSoup
import requests
import re

# %%
#number of total entity present here in this given URL are 697
def url_to_string(url):
  res = requests.get(url)
  html = res.text
  soup = BeautifulSoup(html, 'html5lib')
  for script in soup(["script", "style", 'aside']):
        script.extract()
  return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.nytimes.com/live/2021/04/29/sports/nfl-draft')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 697

# %%
# number of unique labels in given URL is 17
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 86,
#          'DATE': 93,
#          'EVENT': 4,
#          'FAC': 6,
#          'GPE': 66,
#          'LAW': 1,
#          'LOC': 4,
#          'MONEY': 3,
#          'NORP': 12,
#          'ORDINAL': 52,
#          'ORG': 92,
#          'PERCENT': 1,
#          'PERSON': 211,
#          'PRODUCT': 2,
#          'QUANTITY': 16,
#          'TIME': 46,
#          'WORK_OF_ART': 2})

# %%
#The following are three most frequent tokens.

items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('first', 20), ('6', 11), ('Alabama', 9)]

# %%
#One sentence is selcted randomly from the article
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# The Patriots didn’t even have to trade up to take Jones, who at worst will back up Cam Newton this season, so good to see things finally working out for them.

# %%
# used displacy.render to generate the raw markup.
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patriots
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  didn’t even have to trade up to take Jones, who at worst will back up
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cam Newton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="42e41e5a28754c71bee15884cb61e7f7-0" class="displacy" width="3890" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Patriots</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
# ...

# %%
#extraction of part-of-speech and lemmatization of this sentence.
[(x.orth_,x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences[20])) if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Patriots', 'PROPN', 'Patriots'),
#  ('trade', 'VERB', 'trade'),
#  ('Jones', 'PROPN', 'Jones'),
#  ('worst', 'ADJ', 'bad'),
#  ('Cam', 'PROPN', 'Cam'),
#  ('Newton', 'PROPN', 'Newton'),
#  ('season', 'NOUN', 'season'),
#  ('good', 'ADJ', 'good'),
#  ('things', 'NOUN', 'thing'),
#  ('finally', 'ADV', 'finally'),
#  ('working', 'VERB', 'work')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[40])).ents])
# Out:
# {'Tampa Bay': 'FAC'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(The, 'O', ''), (Patriots, 'B', 'PERSON'), (did, 'O', ''), (n’t, 'O', ''), (even, 'O', ''), (have, 'O', ''), (to, 'O', ''), (trade, 'O', ''), (up, 'O', ''), (to, 'O', ''), (take, 'O', ''), (Jones, 'O', ''), (,, 'O', ''), (who, 'O', ''), (at, 'O', ''), (worst, 'O', ''), (will, 'O', ''), (back, 'O', ''), (up, 'O', ''), (Cam, 'B', 'PERSON'), (Newton, 'I', 'PERSON'), (this, 'B', 'DATE'), (season, 'I', 'DATE'), (,, 'O', ''), (so, 'O', ''), (good, 'O', ''), (to, 'O', ''), (see, 'O', ''), (things, 'O', ''), (finally, 'O', ''), (working, 'O', ''), (out, 'O', ''), (for, 'O', ''), (them, 'O', ''), (., 'O', '')]

# %%
#visualization of the entity of the entire article.

displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N.F.L. Draft Picks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Analysis: How Round 1 Unfolded -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                                                   SectionsSEARCHSkip to contentSkip to site
# ...
